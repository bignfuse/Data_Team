# %%
from crop import save_cropped_image
from file_utils import split_and_save_pdf_images,is_new_form
import os
from align import alignImages
from glob import glob
import pandas as pd
pdf_path="input_data"
label=open("label.txt","w")
from time import time
for p in glob(pdf_path+"/*.pdf"):
    t1=time()
    saved_pdf=split_and_save_pdf_images(p)
    unique_id= p.split('/')[-1].split('.')[0]
    page_3_img_path = os.path.join(saved_pdf,"3.jpg")
    form_type= is_new_form(page_3_img_path)
    if form_type== True:
        form_type="new"
        std_json_path=f"{form_type}/standard_json_files/"
        key_json_path=f"{form_type}/key_value_mapping_json_files/"
    elif form_type==False:
        form_type="old"
        std_json_path=f"{form_type}/standard_json_files/"
        key_json_path=f"{form_type}/key_value_mapping_json_files/"
    for n,c in enumerate(os.listdir(saved_pdf)):
        if n>2:
            break
        pdf_image_path=os.path.join(saved_pdf,c)
        aligned_img=alignImages(pdf_image_path,f"{form_type}/template_image/template_{c.split('.')[0]}.jpg")
        save_cropped_image(aligned_img,pdf_image_path,std_json_path,key_json_path,form_type)
    data=pd.read_csv(f"{pdf_path}/final_data.csv")
    if data.index.name != "UniequeId":
        data=data.set_index("UniequeId")
    crop_dir=f"{form_type}_cropped/{unique_id}"
    in_name=0
    key_in=[]
    for crop in os.listdir(crop_dir):
        key_name=crop.split("_")
        if len(key_name)>2:
            key_name='_'.join(key_name[1:len(key_name)]).split(".")[0]
        else:
            key_name= key_name[-1].split(".")[0]
        if(key_name in list(data.columns)):
            key_in.append(key_name)
            values=data.loc[unique_id,key_name]
            if type(values)== str:
                values=values.title()
            label.write(f"{crop_dir}/{crop} {values}\n")
        else:
            label.write(f"{crop_dir}/{crop} check\n")
    print("remaining: ",list(set(data.columns) - set(key_in)))
    print("Total time taken:",time()-t1)
            
label.close()
# Out:
# ---------------------Splitting Pdf---------------------
# saved_pdf_images/CAP-0000000000000000078/
# input_data/CAP-0000000000000000078.pdf
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000078/1.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000078/2.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000078/3.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000078/4.jpg
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 41/41 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 81ms/step
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# remaining:  ['Unnamed: 0']
# Total time taken: 18.99732518196106
# ---------------------Splitting Pdf---------------------
# saved_pdf_images/CAP-0000000000000000148/
# input_data/CAP-0000000000000000148.pdf
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000148/1.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000148/2.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000148/3.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000148/4.jpg
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 23/23 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 153ms/step
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# remaining:  ['Mobile_Number_2', 'Unnamed: 0']
# Total time taken: 13.682339191436768
# ---------------------Splitting Pdf---------------------
# saved_pdf_images/CAP-0000000000000000016/
# input_data/CAP-0000000000000000016.pdf
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000016/1.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000016/2.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000016/3.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000016/4.jpg
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 40/40 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 83ms/step
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# remaining:  ['Unnamed: 0']
# Total time taken: 20.33213472366333
# ---------------------Splitting Pdf---------------------
# saved_pdf_images/CAP-0000000000000000111/
# input_data/CAP-0000000000000000111.pdf
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000111/1.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000111/2.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000111/3.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000111/4.jpg
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 27/27 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 90ms/step
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# remaining:  ['Mobile_Number_2', 'Unnamed: 0']
# Total time taken: 11.076999187469482
# ---------------------Splitting Pdf---------------------
# saved_pdf_images/CAP-0000000000000000124/
# input_data/CAP-0000000000000000124.pdf
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000124/1.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000124/2.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000124/3.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000124/4.jpg
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 39/39 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 86ms/step
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# remaining:  ['Unnamed: 0']
# Total time taken: 24.970799684524536
# ---------------------Splitting Pdf---------------------
# saved_pdf_images/CAP-0000000000000000083/
# input_data/CAP-0000000000000000083.pdf
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000083/1.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000083/2.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000083/3.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000083/4.jpg
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 46/46 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 123ms/step
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# remaining:  ['Unnamed: 0']
# Total time taken: 24.781307458877563
# ---------------------Splitting Pdf---------------------
# saved_pdf_images/CAP-0000000000000000163/
# input_data/CAP-0000000000000000163.pdf
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000163/1.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000163/2.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000163/3.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000163/4.jpg
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 96/96 [==============================] - 1s 5ms/step
# 1/1 [==============================] - 0s 98ms/step
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# remaining:  ['Unnamed: 0']
# Total time taken: 19.93266224861145
# ---------------------Splitting Pdf---------------------
# saved_pdf_images/CAP-0000000000000000099/
# input_data/CAP-0000000000000000099.pdf
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000099/1.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000099/2.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000099/3.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000099/4.jpg
# 1/1 [==============================] - 0s 297ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 81ms/step
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# remaining:  ['Unnamed: 0']
# Total time taken: 12.605507850646973
# ---------------------Splitting Pdf---------------------
# saved_pdf_images/CAP-0000000000000000043/
# input_data/CAP-0000000000000000043.pdf
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000043/1.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000043/2.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000043/3.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000043/4.jpg
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 17ms/step
# 7/7 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 78ms/step
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# remaining:  ['Mobile_Number_2', 'Unnamed: 0']
# Total time taken: 8.833222150802612
# ---------------------Splitting Pdf---------------------
# saved_pdf_images/CAP-0000000000000000045/
# input_data/CAP-0000000000000000045.pdf
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000045/1.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000045/2.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000045/3.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000045/4.jpg
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 27/27 [==============================] - 0s 5ms/step
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# remaining:  ['Identification_Document_Issue_Date_in_BS_1', 'Full_Name', 'Permanent_Address_District', 'Identification_Document_Number_1', 'Permanent_House_Number', 'Mother_Name', 'Spouse_Name', 'Father_Name', 'Guardian_Name', 'Email_address_1', 'Daughter', 'Communication_Street_Tole_Name', 'Son', 'Identification_Document_Issue_Place_1', 'Grandfather_Name', 'Communication_Ward_No', 'Permanent_Ward_No', 'Daughter-in-law', 'Date_of_Birth_in_AD', 'Communication_Address_District', 'Account_Scheme', 'Permanent_Address_Municipality_Rural-MC_City', 'Unnamed: 0', 'Father-in-law', 'Permanent_Street_Tole_Name', 'Grandmother_Name', 'Communication_Address_Municipality_Rural-MC_City', 'Telephone_Number_1', 'Mobile_Number_2', 'Mobile_Number_1', 'Communication_House_Number']
# Total time taken: 20.150410652160645
# ---------------------Splitting Pdf---------------------
# saved_pdf_images/CAP-0000000000000000152/
# input_data/CAP-0000000000000000152.pdf
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000152/1.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000152/2.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000152/3.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000152/4.jpg
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 31/31 [==============================] - 0s 5ms/step
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# remaining:  ['Unnamed: 0']
# Total time taken: 20.497926235198975
# ---------------------Splitting Pdf---------------------
# saved_pdf_images/CAP-0000000000000000106/
# input_data/CAP-0000000000000000106.pdf
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000106/1.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000106/2.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000106/3.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000106/4.jpg
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 20/20 [==============================] - 0s 5ms/step
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# remaining:  ['Unnamed: 0']
# Total time taken: 21.530454874038696
# ---------------------Splitting Pdf---------------------
# saved_pdf_images/CAP-0000000000000000080/
# input_data/CAP-0000000000000000080.pdf
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000080/1.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000080/2.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000080/3.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000080/4.jpg
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 35/35 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 86ms/step
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# remaining:  ['Unnamed: 0']
# Total time taken: 19.96674633026123
# ---------------------Splitting Pdf---------------------
# saved_pdf_images/CAP-0000000000000000064/
# input_data/CAP-0000000000000000064.pdf
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000064/1.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000064/2.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000064/3.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000064/4.jpg
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 52/52 [==============================] - 0s 5ms/step
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 10>()
#      26         break
#      27     pdf_image_path=os.path.join(saved_pdf,c)
# ---> 28     aligned_img=alignImages(pdf_image_path,f"{form_type}/template_image/template_{c.split('.')[0]}.jpg")
#      29     save_cropped_image(aligned_img,pdf_image_path,std_json_path,key_json_path,form_type)
#      30 data=pd.read_csv(f"{pdf_path}/final_data.csv")
#
# File ~/Downloads/Fusemachine/NIC/folders_used_for_test/Data_team_crop_map_API/align.py:18, in alignImages(img_path, template_path, file_id, validate_form)
#      16 template = cv2.cvtColor(img_template, cv2.COLOR_BGR2GRAY)
#      17 # orb = cv2.xfeatures2d.SIFT_create()
# ---> 18 kp1, dec1 = orb.detectAndCompute(template, None)
#      19 kp2, dec2 = orb.detectAndCompute(img1_gray, None)
#      21 # bf = cv2.BFMatcher()
#
# KeyboardInterrupt:

# %%
import pandas as pd
df = pd.read_excel('Distict & Municipality.xlsx', sheet_name=None)  
for key,values in df.items(): 
    df[key].to_csv('Test/data_%s.csv'%key)

# %%
import pandas as pd
old_csv=pd.read_csv(f"Test/input_fields.csv")
dit_csv=pd.read_csv("Test/data_District.csv")

code_map=dit_csv.set_index('District Code').to_dict()['District']

dist_ls=["Communication_Address_District","Permanent_Address_District","Identification_Document_Issue_Place_1"]
for dis in dist_ls:
    ch_dist=[]
    for d in old_csv[dis]:
        if d in code_map.keys():
            ch_dist.append(code_map[d])
        else:
            ch_dist.append(d)
        
    old_csv[dis]=ch_dist
old_csv.to_csv("final_data.csv")

# %%
dit_csv=pd.read_csv("Test/data_District.csv")

code_map=dit_csv.set_index('District Code').to_dict()['District']
# Out:
# {'ACHHA': 'ACHHAM',
#  'ARGHA': 'ARGHAKHANCHI',
#  'BAGLU': 'BAGLUNG',
#  'BAITA': 'BAITADI',
#  'BAJHA': 'BAJHANG',
#  'BAJUR': 'BAJURA',
#  'BANKE': 'BANKE',
#  'BARA': 'BARA',
#  'BARDI': 'BARDIYA',
#  'BHAKT': 'BHAKTAPUR',
#  'BHOJP': 'BHOJPUR',
#  'CHITW': 'CHITWAN',
#  'DADEL': 'DADELDHURA',
#  'DAILE': 'DAILEKH',
#  'DANG': 'DANG',
#  'DARCH': 'DARCHULA',
#  'DHADI': 'DHADING',
#  'DHANK': 'DHANKUTA',
#  'DHANU': 'DHANUSHA',
#  'DOLKH': 'DOLAKHA',
#  'DOLPA': 'DOLPA',
#  'DOTI': 'DOTI',
#  'GORKH': 'GORKHA',
#  'GULMI': 'GULMI',
#  'HUMLA': 'HUMLA',
#  'ILAM': 'ILAM',
#  'JAJAR': 'JAJARKOT',
#  'JHAPA': 'JHAPA',
#  'JUMLA': 'JUMLA',
#  'KAILA': 'KAILALI',
#  'KALIK': 'KALIKOT',
#  'KANCH': 'KANCHANPUR',
#  'KAPIL': 'KAPILVASTU',
#  'KASKI': 'KASKI',
#  'KATHM': 'KATHMANDU',
#  'KAVRE': 'KAVREPALANCHOK',
#  'KHOTA': 'KHOTANG',
#  'LALIT': 'LALITPUR',
#  'LAMJU': 'LAMJUNG',
#  'MAHOT': 'MAHOTTARI',
#  'MAKWA': 'MAKWANPUR',
#  'MANAG': 'MANAG',
#  'MORAN': 'MORANG',
#  'MUGU': 'MUGU',
#  'MUSTA': 'MUSTANG',
#  'MYAGD': 'MYAGDI',
#  nan: nan,
#  'NAWAL': 'NAWALPARASI',
#  'NAWEA': 'NAWALPARASI EAST',
#  'NAWWE': 'NAWALPARASI WEST',
#  'NUWAK': 'NUWAKOT',
#  'OKHAL': 'OKHALDHUNGA',
#  'OTHER': 'NOT AVAILABLE',
#  'PALPA': 'PALPA',
#  'PANCH': 'PANCHTHAR',
#  'PARSA': 'PARSA',
#  'PARWA': 'PARBAT',
#  'PYUTH': 'PYUTHAN',
#  'RAMEC': 'RAMECHHAP',
#  'RASUW': 'RASUWA',
#  'RAUTH': 'RAUTHAHAT',
#  'ROLPA': 'ROLPA',
#  'RUKEA': 'RUKUM EAST',
#  'RUKUM': 'RUKUM',
#  'RUKWE': 'RUKUM WEST',
#  'RUPAN': 'RUPANDEHI',
#  'SALYA': 'SALYAN',
#  'SANKH': 'SANKHUWASABHA',
#  'SAPTA': 'SAPTARI',
#  'SARLA': 'SARLAHI',
#  'SIND': 'SINDHUPALCHOK',
#  'SINDH': 'SINDHULI',
#  'SIRAH': 'SIRAHA',
#  'SOLUK': 'SOLUKHUMBU',
#  'SUNSA': 'SUNSARI',
#  'SURKH': 'SURKHET',
#  'SYANG': 'SYANGJA',
#  'TANAH': 'TANAHUN',
#  'TAPLE': 'TAPLEJUNG',
#  'TERHA': 'TERHATHUM',
#  'UDAYP': 'UDAYPUR'}
