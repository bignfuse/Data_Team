# %%
from crop import save_cropped_image
from file_utils import split_and_save_pdf_images,is_new_form
import os
from align import alignImages
from glob import glob
import pandas as pd
pdf_path="input_data"
from time import time

list_pdf=glob(pdf_path+"/*.pdf")
print(list_pdf)
if os.path.isfile("label.txt"):
    with open("label.txt","r") as read_txt:
        f=read_txt.readlines()
        lines=[l.split("/")[1] for l in f]
        last_file=f"input_data/{lines[-1]}.pdf"
        start=list_pdf.index(last_file)
        
else:
    start=-1

label=open("label.txt","a+")


for p in list_pdf[start+1:]:
    t1=time()
    saved_pdf=split_and_save_pdf_images(p)
    unique_id= p.split('/')[-1].split('.')[0]
    page_3_img_path = os.path.join(saved_pdf,"3.jpg")
    form_type= is_new_form(page_3_img_path)
    if form_type== True:
        form_type="new"
        std_json_path=f"{form_type}/standard_json_files/"
        key_json_path=f"{form_type}/key_value_mapping_json_files/"
    elif form_type==False:
        form_type="old"
        std_json_path=f"{form_type}/standard_json_files/"
        key_json_path=f"{form_type}/key_value_mapping_json_files/"
    for n,c in enumerate(os.listdir(saved_pdf)):
        if n>2:
            break
        pdf_image_path=os.path.join(saved_pdf,c)
        aligned_img=alignImages(pdf_image_path,f"{form_type}/template_image/template_{c.split('.')[0]}.jpg")
        save_cropped_image(aligned_img,pdf_image_path,std_json_path,key_json_path,form_type)
    data=pd.read_csv(f"{pdf_path}/final_data.csv")
    if data.index.name != "UniequeId":
        data=data.set_index("UniequeId")
    crop_dir=f"{form_type}_cropped/{unique_id}"
    in_name=0
    key_in=[]
    for crop in os.listdir(crop_dir):
        key_name=crop.split("_")
        if len(key_name)>2:
            key_name='_'.join(key_name[1:len(key_name)]).split(".")[0]
        else:
            key_name= key_name[-1].split(".")[0]
        if(key_name in list(data.columns)):
            key_in.append(key_name)
            values=data.loc[unique_id,key_name]
            if type(values)== str:
                values=values.title()
            label.write(f"{crop_dir}/{crop} {values}\n")
        else:
            label.write(f"{crop_dir}/{crop} check\n")
    print("remaining: ",list(set(data.columns) - set(key_in)))
    print("Total time taken:",time()-t1)
            
label.close()
# Out:
# ['input_data/CAP-0000000000000000078.pdf', 'input_data/CAP-0000000000000000148.pdf', 'input_data/CAP-0000000000000000016.pdf', 'input_data/CAP-0000000000000000111.pdf', 'input_data/CAP-0000000000000000124.pdf', 'input_data/CAP-0000000000000000083.pdf', 'input_data/CAP-0000000000000000163.pdf', 'input_data/CAP-0000000000000000099.pdf', 'input_data/CAP-0000000000000000043.pdf', 'input_data/CAP-0000000000000000045.pdf', 'input_data/CAP-0000000000000000152.pdf', 'input_data/CAP-0000000000000000106.pdf', 'input_data/CAP-0000000000000000080.pdf', 'input_data/CAP-0000000000000000064.pdf', 'input_data/CAP-0000000000000000015.pdf', 'input_data/CAP-0000000000000000169.pdf', 'input_data/CAP-0000000000000000116.pdf', 'input_data/CAP-0000000000000000072.pdf', 'input_data/CAP-0000000000000000014.pdf', 'input_data/CAP-0000000000000000154.pdf', 'input_data/CAP-0000000000000000109.pdf', 'input_data/CAP-0000000000000000077.pdf', 'input_data/CAP-0000000000000000149.pdf', 'input_data/CAP-0000000000000000050.pdf', 'input_data/CAP-0000000000000000047.pdf', 'input_data/CAP-0
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000174/1.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000174/2.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000174/3.jpg
# -------------Image saved at:: saved_pdf_images/CAP-0000000000000000174/4.jpg
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 20/20 [==============================] - 0s 5ms/step
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# ---------------------Aligning Image---------------------
# ---------------------Cropping image ---------------------
# remaining:  ['Unnamed: 0']
# Total time taken: 25.560669898986816
# ---------------------Splitting Pdf---------------------
# saved_pdf_images/CAP-0000000000000000167/
# input_data/CAP-0000000000000000167.pdf
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pdf2image/pdf2image.py:479, in pdfinfo_from_path(pdf_path, userpw, poppler_path, rawdates, timeout)
#     478 if "Pages" not in d:
# --> 479     raise ValueError
#     481 return d
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# PDFPageCountError                         Traceback (most recent call last)
# Input In [2], in <cell line: 25>()
#      25 for p in list_pdf[start+1:]:
#      26     t1=time()
# ---> 27     saved_pdf=split_and_save_pdf_images(p)
#      28     unique_id= p.split('/')[-1].split('.')[0]
#      29     page_3_img_path = os.path.join(saved_pdf,"3.jpg")
#
# File ~/Downloads/Fusemachine/NIC/folders_used_for_test/Data_team_crop_map_API/file_utils.py:29, in split_and_save_pdf_images(pdf_path)
#      27         os.makedirs(save_directory)
#      28 print(pdf_path)
# ---> 29 images = convert_from_path(pdf_path)
#      30 for i in range(len(images)):
#      31     if i<=3:
#
# File ~/anaconda3/lib/python3.9/site-packages/pdf2image/pdf2image.py:98, in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only, use_pdftocairo, timeout, hide_annotations)
#      95 if isinstance(poppler_path, pathlib.PurePath):
#      96     poppler_path = poppler_path.as_posix()
# ---> 98 page_count = pdfinfo_from_path(pdf_path, userpw, poppler_path=poppler_path)["Pages"]
#     100 # We start by getting the output format, the buffer processing function and if we need pdftocairo
#     101 parsed_fmt, final_extension, parse_buffer_func, use_pdfcairo_format = _parse_format(
#     102     fmt, grayscale
#     103 )
#
# File ~/anaconda3/lib/python3.9/site-packages/pdf2image/pdf2image.py:488, in pdfinfo_from_path(pdf_path, userpw, poppler_path, rawdates, timeout)
#     484     raise PDFInfoNotInstalledError(
#     485         "Unable to get page count. Is poppler installed and in PATH?"
#     486     )
#     487 except ValueError:
# --> 488     raise PDFPageCountError(
#     489         "Unable to get page count.\n%s" % err.decode("utf8", "ignore")
#     490     )
#
# PDFPageCountError: Unable to get page count.
# I/O Error: Couldn't open file 'input_data/CAP-0000000000000000167.pdf': No such file or directory.

# %%
import pandas as pd
df = pd.read_excel('Distict & Municipality.xlsx', sheet_name=None)  
for key,values in df.items(): 
    df[key].to_csv('Test/data_%s.csv'%key)

# %%
import pandas as pd
old_csv=pd.read_csv(f"Test/input_fields.csv")
dit_csv=pd.read_csv("Test/data_District.csv")

code_map=dit_csv.set_index('District Code').to_dict()['District']

dist_ls=["Communication_Address_District","Permanent_Address_District","Identification_Document_Issue_Place_1"]
for dis in dist_ls:
    ch_dist=[]
    for d in old_csv[dis]:
        if d in code_map.keys():
            ch_dist.append(code_map[d])
        else:
            ch_dist.append(d)
        
    old_csv[dis]=ch_dist
old_csv.to_csv("final_data.csv")

# %%
dit_csv=pd.read_csv("Test/data_District.csv")

code_map=dit_csv.set_index('District Code').to_dict()['District']
# Out:
# {'ACHHA': 'ACHHAM',
#  'ARGHA': 'ARGHAKHANCHI',
#  'BAGLU': 'BAGLUNG',
#  'BAITA': 'BAITADI',
#  'BAJHA': 'BAJHANG',
#  'BAJUR': 'BAJURA',
#  'BANKE': 'BANKE',
#  'BARA': 'BARA',
#  'BARDI': 'BARDIYA',
#  'BHAKT': 'BHAKTAPUR',
#  'BHOJP': 'BHOJPUR',
#  'CHITW': 'CHITWAN',
#  'DADEL': 'DADELDHURA',
#  'DAILE': 'DAILEKH',
#  'DANG': 'DANG',
#  'DARCH': 'DARCHULA',
#  'DHADI': 'DHADING',
#  'DHANK': 'DHANKUTA',
#  'DHANU': 'DHANUSHA',
#  'DOLKH': 'DOLAKHA',
#  'DOLPA': 'DOLPA',
#  'DOTI': 'DOTI',
#  'GORKH': 'GORKHA',
#  'GULMI': 'GULMI',
#  'HUMLA': 'HUMLA',
#  'ILAM': 'ILAM',
#  'JAJAR': 'JAJARKOT',
#  'JHAPA': 'JHAPA',
#  'JUMLA': 'JUMLA',
#  'KAILA': 'KAILALI',
#  'KALIK': 'KALIKOT',
#  'KANCH': 'KANCHANPUR',
#  'KAPIL': 'KAPILVASTU',
#  'KASKI': 'KASKI',
#  'KATHM': 'KATHMANDU',
#  'KAVRE': 'KAVREPALANCHOK',
#  'KHOTA': 'KHOTANG',
#  'LALIT': 'LALITPUR',
#  'LAMJU': 'LAMJUNG',
#  'MAHOT': 'MAHOTTARI',
#  'MAKWA': 'MAKWANPUR',
#  'MANAG': 'MANAG',
#  'MORAN': 'MORANG',
#  'MUGU': 'MUGU',
#  'MUSTA': 'MUSTANG',
#  'MYAGD': 'MYAGDI',
#  nan: nan,
#  'NAWAL': 'NAWALPARASI',
#  'NAWEA': 'NAWALPARASI EAST',
#  'NAWWE': 'NAWALPARASI WEST',
#  'NUWAK': 'NUWAKOT',
#  'OKHAL': 'OKHALDHUNGA',
#  'OTHER': 'NOT AVAILABLE',
#  'PALPA': 'PALPA',
#  'PANCH': 'PANCHTHAR',
#  'PARSA': 'PARSA',
#  'PARWA': 'PARBAT',
#  'PYUTH': 'PYUTHAN',
#  'RAMEC': 'RAMECHHAP',
#  'RASUW': 'RASUWA',
#  'RAUTH': 'RAUTHAHAT',
#  'ROLPA': 'ROLPA',
#  'RUKEA': 'RUKUM EAST',
#  'RUKUM': 'RUKUM',
#  'RUKWE': 'RUKUM WEST',
#  'RUPAN': 'RUPANDEHI',
#  'SALYA': 'SALYAN',
#  'SANKH': 'SANKHUWASABHA',
#  'SAPTA': 'SAPTARI',
#  'SARLA': 'SARLAHI',
#  'SIND': 'SINDHUPALCHOK',
#  'SINDH': 'SINDHULI',
#  'SIRAH': 'SIRAHA',
#  'SOLUK': 'SOLUKHUMBU',
#  'SUNSA': 'SUNSARI',
#  'SURKH': 'SURKHET',
#  'SYANG': 'SYANGJA',
#  'TANAH': 'TANAHUN',
#  'TAPLE': 'TAPLEJUNG',
#  'TERHA': 'TERHATHUM',
#  'UDAYP': 'UDAYPUR'}
